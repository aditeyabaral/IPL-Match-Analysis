# %%
setwd('C:/Users/Aditeya/Desktop/Aditeya/PES University/2nd Year/R/R Project')

# %%
df = read.csv("matches.csv")
df$umpire3 = NULL

# %%
for (i in seq(1,756,5))
{
  df$umpire1[i]=""
}
for (i in seq(1,756,15))
{
  df$umpire2[i]=""
}
for (i in seq(1,756,10))
{
  if(df$win_by_runs[i]==0)
  {
    df$win_by_runs[i]=NaN
  }
}
for (i in seq(1,756,5))
{
  df$result[i]=""
}
# Out:
# Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# "invalid factor level, NA generated"Warning message in `[<-.factor`(`*tmp*`, i, value = ""):
# ...

# %%
head(df)
# Out:
#   id season city      date       team1
# 1 1  2017   Hyderabad 2017-04-05 Sunrisers Hyderabad
# 2 2  2017   Pune      2017-04-06 Mumbai Indians
# 3 3  2017   Rajkot    2017-04-07 Gujarat Lions
# 4 4  2017   Indore    2017-04-08 Rising Pune Supergiant
# 5 5  2017   Bangalore 2017-04-08 Royal Challengers Bangalore
# 6 6  2017   Hyderabad 2017-04-09 Gujarat Lions
#   team2                       toss_winner                 toss_decision result
# 1 Royal Challengers Bangalore Royal Challengers Bangalore field         NA
# 2 Rising Pune Supergiant      Rising Pune Supergiant      field         normal
# 3 Kolkata Knight Riders       Kolkata Knight Riders       field         normal
# 4 Kings XI Punjab             Kings XI Punjab             field         normal
# 5 Delhi Daredevils            Royal Challengers Bangalore bat           normal
# 6 Sunrisers Hyderabad         Sunrisers Hyderabad         field         NA
#   dl_applied winner                      win_by_runs win_by_wickets
# ...

# %%
write.csv(df,'iplmatches.csv')
